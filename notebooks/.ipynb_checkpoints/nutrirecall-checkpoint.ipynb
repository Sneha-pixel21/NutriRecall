# %%
USE_LOCAL = True

# %%
import pandas as pd
import os
from datetime import datetime

# %%
file_path = "../data/health_logs.csv"

if not os.path.exists(file_path):
    df = pd.DataFrame(columns=["Date", "Weight", "Protein", "Sleep_hours", "Workout"])
    df.to_csv(file_path, index=False)
    print("File Created")
else:
    print("File Exists")
# Out:
# File Exists

# %%
date = datetime.today().strftime('%y-%m-%d')

weight = float(input("Enter weigth(kgs): "))
protein = float (input("Protein Intake(g): "))
sleep = float(input("Sleep Hours: "))
workout = int(input("Workout? (1= yes, 0= no): "))
# Out:
# Enter weigth(kgs):  56
# Protein Intake(g):  20
# Sleep Hours:  7
# Workout? (1= yes, 0= no):  1

# %%
new_entry = pd.DataFrame([{
    "Date": date,
    "Weight": weight,
    "Protein": protein,
    "Sleep_hours": sleep,
    "Workout": workout
}])

new_entry.to_csv(file_path, mode='a', header=False, index=False)
print("Entry saved!")
# Out:
# Entry saved!

# %%
data = pd.read_csv(file_path)
data.reset_index(drop=True)
data
# Out:
#        Date  Weight  Protein  Sleep_hours  Workout
# 0  26-04-08    57.2     20.0          7.0        1
# 1  26-04-22    56.0     20.0          7.0        1

# %%
data = pd.read_csv("../data/health_logs.csv")
data['Date'] = pd.to_datetime(data['Date'])
data = data.sort_values(by='Date')
# Out:
# C:\Users\rajde\AppData\Local\Temp\ipykernel_14104\1623079151.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Date'] = pd.to_datetime(data['Date'])

# %%
data ['Protein_required'] = data['Weight'] * 1.6
data ['Protein_score'] = data['Protein']/ data['Protein_required']
data ['sleep_score'] = data['Sleep_hours']/7
data ['workout_score'] = data['Workout']

# %%
data['Protein_score'] = data['Protein_score'].clip(0,1)
data['sleep_score'] = data['sleep_score'].clip(0,1)

# %%
data['health_score'] =(
    0.4 *data['Protein_score'] +
    0.3 * data['sleep_score'] +
    0.3 * data['workout_score']
)

# %%
data['health_score_10'] = (data['health_score'] *9) +1

# %%
recent = data.tail(7)

avg_health = recent['health_score'].mean()
avg_protein = recent['Protein'].mean()
avg_sleep = recent['Sleep_hours'].mean()
workout_days = recent['Workout'].sum()

# %%
def detect_patterns(data):
    recent = data.tail(7)
    issues = []

    if recent['Protein'].mean() < recent['Protein_required'].mean():
        issues.append("Consistently low protein intake")

    if recent['Sleep_hours'].mean() < 6:
        issues.append("Poor sleep pattern")

    if recent['Workout'].sum() < 3:
        issues.append("Low workout consistency")

    if recent['health_score'].mean() < 0.6:
        issues.append("Overall lifestyle needs improvement")

    return issues

# %%
def generate_insights(data):
    recent = data.tail(7)
    issues = detect_patterns(data)

    insight = f"""
    Last 7 Days Summary:
    Avg Protein: {recent['Protein'].mean():.1f}g
    Avg sleep: {recent['Sleep_hours'].mean():.1f}hrs
    Workout Days: {recent['Workout'].sum()}/7
    Health score: {recent['health_score_10'].mean():.1f} / 10

    Key Issues:
    {", ".join(issues) if issues else "No Major Issues"}
    """
    return insight

# %%
print(generate_insights(data))
# Out:
#     Last 7 Days Summary:
#     Avg Protein: 20.0g
#     Avg sleep: 7.0hrs
#     Workout Days: 2/7
#     Health score: 7.2 / 10
#
#     Key Issues:
#     Consistently low protein intake, Low workout consistency

# %%
import ollama

# %%
response = ollama.chat(
    model='phi3:mini',
    messages=[
        {"role": "user", "content": "Say hello"}
    ]
)

print(response['message']['content'])
# Out:
# Hello! How can I help you today?

# %%
knowledge = [
    "Protein intake for muscle growth should be 1.6 to 2.2 grams per kg body weight, and Optimal per meal: 0.3 – 0.5 g/kg",
    "Sleeping less than 6 hours reduces recovery and muscle growth.",
    "Consistent workouts are required to build muscle.",
    "Low protein intake can prevent muscle gain.",
    "High-quality sources: Eggs, chicken, fish Dairy (curd, paneer, milk) Plant: lentils, chickpeas, tofu",
    "Ideal sleep: 7–9 hours/night",
    "IF protein < 1.6 g/kg → suggest increasing intake",
    "IF sleep < 6 hrs → warn about recovery drop"
    "Recovery is as important as training for muscle growth."
]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorize = TfidfVectorizer()
X = vectorize.fit_transform(knowledge)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
def retrieve_knowledge(query):
    query_vec = vectorize.transform([query])
    similarity = cosine_similarity(query_vec, X)

    index = similarity.argmax()
    return knowledge[index]

# %%
print(retrieve_knowledge("muscle growth"))
# Out:
# Sleeping less than 6 hours reduces recovery and muscle growth.

# %%
def get_data_insight():
    return generate_insights(data)


def get_knowledge(query):
    return retrieve_knowledge(query)

# %%
import chromadb

# %%
client = chromadb.Client()
collection = client.get_or_create_collection(name= "NutriRecall_Memory")

# %%
def store_memory(insight, id):
    collection.add(
        documents=[insight],
        ids=[str(id)]
    )

# %%
def retrieve_memory(query):
    results = collection.query(
        query_texts=[query],
        n_results=2
    )

    docs = results['documents'][0]
    

    return " \n ".join(docs)

# %%
def nutrirecall_ai(query, data):

    insight = generate_insights(data)
    knowledge_piece = retrieve_knowledge(query)
    memory = retrieve_memory(query)

    prompt = f"""
You are a smart fitness and nutrition assistant, works on straight facts and nurtirional balance.

use the following tools:
- User data insights
- Nutritional Knowledge

user data:
{insight}

Relevant Knowledge:
{knowledge_piece}

User Question:
{query}

Analyze the situation step by step and give a clear, personalized, and practical answer, the answer should be not to long, in points minimal and direct. 
"""
    response = ollama.chat(
        model= 'phi3:mini',
        messages = [{"role": "user","content": prompt}]
    )

    return response ['message']['content']

# %%
insight_text = generate_insights(data)
store_memory(insight_text, id=2)

# %%
print(retrieve_memory("muscle growth"))
# Out:
#     Last 7 Days Summary:
#     Avg Protein: 20.0g
#     Avg sleep: 7.0hrs
#     Workout Days: 2/7
#     Health score: 7.2 / 10
#
#     Key Issues:
#     Consistently low protein intake, Low workout consistency

# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in c:\users\rajde\anaconda3\lib\site-packages (2.16.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\rajde\anaconda3\lib\site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\rajde\anaconda3\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\rajde\anaconda3\lib\site-packages (from openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\rajde\anaconda3\lib\site-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\rajde\anaconda3\lib\site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in c:\users\rajde\anaconda3\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\rajde\anaconda3\lib\site-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\rajde\anaconda3\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\rajde\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in c:\users\rajde\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\rajde\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\rajde\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\rajde\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\rajde\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\rajde\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: colorama in c:\users\rajde\anaconda3\lib\site-packages (from tqdm>4->openai) (0.4.6)

# %%
from openai import OpenAI

# %%
import os
client = OpenAI(
    api_key = os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
    )
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[83], line 2
#       1 import os
# ----> 2 client = OpenAI(
#       3     api_key = os.getenv("GROQ_API_KEY"),
#       4     base_url="https://api.groq.com/openai/v1"
#       5     )
#
# File ~\anaconda3\Lib\site-packages\openai\_client.py:137, in OpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     135     api_key = os.environ.get("OPENAI_API_KEY")
#     136 if api_key is None:
# --> 137     raise OpenAIError(
#     138         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     139     )
#     140 if callable(api_key):
#     141     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
